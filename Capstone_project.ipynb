# %% [markdown]
# # Carlo Nicolò - IBM Coursera Capstone Project

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

import numpy as np # library to handle data in a vectorized manner

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes
#=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# ...
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::numba==0.41.0=py37h962f231_0
#   - defaults/linux-64::blaze==0.11.3=py37_0
#   - defaults/linux-64::anaconda==2018.12=py37_0
# done
#
# ## Package Plan ##
#
#   environment location: /home/karlitos/anaconda3
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2019.03  |           py37_0           5 KB
#     anaconda-custom            |           py37_1           3 KB
#     pyrsistent-0.15.5          |   py37h516909a_0          89 KB  conda-forge
#     soupsieve-1.9.4            |           py37_0          57 KB  conda-forge
#     tbb-2019.9                 |       hc9558a2_0         1.4 MB  conda-forge
# ...

# %% [markdown]
# ### Taking info from wikipedia

# %%
website_url = requests.get("https://it.wikipedia.org/wiki/Monaco_di_Baviera").text

# %%
soup = BeautifulSoup(website_url,'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="it">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Monaco di Baviera - Wikipedia
#   </title>
#   <script>
# ...

# %%
My_table = soup.find('table',{'class':'wikitable sortable'})
My_table
# Out:
# <table class="wikitable sortable" style="text-align:right; font-size:90%;">
# <tbody><tr style="text-align:center;">
# <th style="background:#ccc">N°</th>
# <th>Nome</th>
# <th>Abitanti</th>
# <th>Superficie/ha</th>
# <th>Abitanti/ha</th>
# <th class="unsortable">Quartieri
# </th></tr>
# <tr>
# <td style="text-align:center">1</td>
# <td><a href="/wiki/Altstadt-Lehel" title="Altstadt-Lehel">Altstadt-Lehel</a></td>
# <td>19 207</td>
# <td>314,56</td>
# <td>61</td>
# <td>Graggenauer Viertel<br/>Angerviertel<br/>Hackenviertel<br/>Kreuzviertel<br/><a href="/wiki/Lehel_(Monaco_di_Baviera)" title="Lehel (Monaco di Baviera)">Lehel</a><br/><a href="/wiki/Englischer_Garten" title="Englischer Garten">Englischer Garten</a> Süd
# </td></tr>
# <tr>
# <td style="text-align:center">2</td>
# <td><a href="/wiki/Ludwigsvorstadt-Isarvorstadt" title="Ludwigsvorstadt-Isarvorstadt">Ludwigsvorstadt-Isarvorstadt</a></td>
# <td>47 357</td>
# <td>440,15</td>
# <td>108</td>
# ...

# %%
links = My_table.findAll('a')
links
# Out:
# [<a href="/wiki/Altstadt-Lehel" title="Altstadt-Lehel">Altstadt-Lehel</a>,
#  <a href="/wiki/Lehel_(Monaco_di_Baviera)" title="Lehel (Monaco di Baviera)">Lehel</a>,
#  <a href="/wiki/Englischer_Garten" title="Englischer Garten">Englischer Garten</a>,
#  <a href="/wiki/Ludwigsvorstadt-Isarvorstadt" title="Ludwigsvorstadt-Isarvorstadt">Ludwigsvorstadt-Isarvorstadt</a>,
#  <a href="/wiki/Deutsches_Museum" title="Deutsches Museum">Deutsches Museum</a>,
#  <a href="/wiki/Maxvorstadt" title="Maxvorstadt">Maxvorstadt</a>,
#  <a href="/wiki/K%C3%B6nigsplatz" title="Königsplatz">Königsplatz</a>,
#  <a href="/wiki/Schwabing-West" title="Schwabing-West">Schwabing-West</a>,
#  <a href="/wiki/Au-Haidhausen" title="Au-Haidhausen">Au-Haidhausen</a>,
#  <a href="/wiki/Maximilianeum" title="Maximilianeum">Maximilianeum</a>,
#  <a href="/wiki/Sendling" title="Sendling">Sendling</a>,
#  <a href="/wiki/Sendling-Westpark" title="Sendling-Westpark">Sendling-Westpark</a>,
# ...

# %%
Location = []
for link in links:
    Location.append(link.get('title'))
    
# print(Location)

# del Location[0:2]

#Location

Location_filtered = [x for x in Location if x is not None]

len(Location_filtered)
Location_filtered
# Out:
# ['Altstadt-Lehel',
#  'Lehel (Monaco di Baviera)',
#  'Englischer Garten',
#  'Ludwigsvorstadt-Isarvorstadt',
#  'Deutsches Museum',
#  'Maxvorstadt',
#  'Königsplatz',
#  'Schwabing-West',
#  'Au-Haidhausen',
#  'Maximilianeum',
#  'Sendling',
#  'Sendling-Westpark',
#  'Schwanthalerhöhe',
#  'Neuhausen-Nymphenburg',
#  'Oberwiesenfeld',
#  'Moosach (Monaco di Baviera)',
#  'Milbertshofen-Am Hart',
#  'Schwabing-Freimann',
#  'Freimann (metropolitana di Monaco di Baviera)',
#  'Münchner Freiheit',
#  'Bogenhausen',
#  'Berg am Laim',
#  'Trudering-Riem',
#  'Ramersdorf-Perlach',
#  'Obergiesing-Fasangarten',
#  'Untergiesing-Harlaching',
#  'Thalkirchen-Obersendling-Forstenried-Fürstenried-Solln',
#  'Hadern',
#  'Pasing-Obermenzing',
#  'Aubing-Lochhausen-Langwied',
#  'Allach-Untermenzing',
#  'Feldmoching-Hasenbergl',
#  'Laim']

# %% [markdown]
# ### Creating an array with all munich locations

# %%
b = "(Monaco di Baviera)"
d = "(metropolitana di Monaco di Baviera)"

#c = Location_filtered[1]
e = Location_filtered[18]

#print(c.replace(b, ''))
print(e.replace(d, ''))

location_munich = []


# Formatting the right way the name of the quarter in order to don't have problems when
# we will search for latitutde and longitude
for x in Location_filtered:
    
    a = x.replace(b,'')
    
    location_munich.append(a)

location_munich[18] = e.replace(d, '')    
location_munich
# Out:
# Freimann
# ['Altstadt-Lehel',
#  'Lehel ',
#  'Englischer Garten',
#  'Ludwigsvorstadt-Isarvorstadt',
#  'Deutsches Museum',
#  'Maxvorstadt',
#  'Königsplatz',
#  'Schwabing-West',
#  'Au-Haidhausen',
#  'Maximilianeum',
#  'Sendling',
#  'Sendling-Westpark',
#  'Schwanthalerhöhe',
#  'Neuhausen-Nymphenburg',
#  'Oberwiesenfeld',
#  'Moosach ',
#  'Milbertshofen-Am Hart',
#  'Schwabing-Freimann',
#  'Freimann ',
#  'Münchner Freiheit',
#  'Bogenhausen',
#  'Berg am Laim',
#  'Trudering-Riem',
#  'Ramersdorf-Perlach',
#  'Obergiesing-Fasangarten',
#  'Untergiesing-Harlaching',
#  'Thalkirchen-Obersendling-Forstenried-Fürstenried-Solln',
#  'Hadern',
#  'Pasing-Obermenzing',
#  'Aubing-Lochhausen-Langwied',
#  'Allach-Untermenzing',
#  'Feldmoching-Hasenbergl',
#  'Laim']

# %%
df = pd.DataFrame()
df['Location'] = location_munich
df
# Out:
#                                              Location
# 0                                      Altstadt-Lehel
# 1                                              Lehel
# 2                                   Englischer Garten
# 3                        Ludwigsvorstadt-Isarvorstadt
# 4                                    Deutsches Museum
# 5                                         Maxvorstadt
# 6                                         Königsplatz
# 7                                      Schwabing-West
# 8                                       Au-Haidhausen
# 9                                       Maximilianeum
# 10                                           Sendling
# 11                                  Sendling-Westpark
# 12                                   Schwanthalerhöhe
# 13                              Neuhausen-Nymphenburg
# 14                                     Oberwiesenfeld
# 15                                           Moosach
# ...

# %%
def get_coords_local(location, output_as='center'):
    """
    get the bounding box of a locality in WGS84 given its name

    Parameters
    ----------
    localidad : str
        name of the country in english and lowercase
    output_as : 'str
        chose from 'boundingbox' or 'center'. 
         - 'boundingbox' for [latmin, latmax, lonmin, lonmax]
         - 'center' for [latcenter, loncenter]

    Returns
    -------
    output : list
        list with coordinates as str
    """
    # create url
    url = '{0}{1}{2}'.format('http://nominatim.openstreetmap.org/search.php?q=',
                             location+', Munich',
                             '&format=json&polygon=0')
    response = requests.get(url).json()[0]

    # parse response to list
    if output_as == 'boundingbox':
        lst = response[output_as]
        output = [float(i) for i in lst]
    if output_as == 'center':
        lst = [response.get(key) for key in ['lat','lon']]
        output = [float(i) for i in lst]
    return output

# %%
df2 = df.copy()

latitudeCln = []
longitudeCln = []
for index, row in df2.iterrows():
    print(row[0])
    lat, long = get_coords_local(location=row[0], output_as='center')
    latitudeCln.append(lat)
    longitudeCln.append(long)

df2['Latitude'] = latitudeCln
df2['Longitude'] = longitudeCln

df2.shape
# Out:
# Altstadt-Lehel
# Lehel
# Englischer Garten
# Ludwigsvorstadt-Isarvorstadt
# Deutsches Museum
# Maxvorstadt
# Königsplatz
# Schwabing-West
# Au-Haidhausen
# Maximilianeum
# Sendling
# Sendling-Westpark
# Schwanthalerhöhe
# Neuhausen-Nymphenburg
# Oberwiesenfeld
# Moosach
# Milbertshofen-Am Hart
# Schwabing-Freimann
# Freimann
# Münchner Freiheit
# Bogenhausen
# Berg am Laim
# Trudering-Riem
# Ramersdorf-Perlach
# Obergiesing-Fasangarten
# Untergiesing-Harlaching
# Thalkirchen-Obersendling-Forstenried-Fürstenried-Solln
# Hadern
# Pasing-Obermenzing
# Aubing-Lochhausen-Langwied
# Allach-Untermenzing
# Feldmoching-Hasenbergl
# Laim
# (33, 3)

# %%
df2
# Out:
#                                              Location   Latitude  Longitude
# 0                                      Altstadt-Lehel  48.137828  11.574582
# 1                                              Lehel   48.138712  11.588795
# 2                                   Englischer Garten  48.165110  11.606611
# 3                        Ludwigsvorstadt-Isarvorstadt  48.131771  11.555809
# 4                                    Deutsches Museum  48.130039  11.582888
# 5                                         Maxvorstadt  48.146570  11.571445
# 6                                         Königsplatz  48.146316  11.565630
# 7                                      Schwabing-West  48.164417  11.570364
# 8                                       Au-Haidhausen  48.128753  11.590536
# 9                                       Maximilianeum  48.136134  11.595202
# 10                                           Sendling  48.118012  11.539083
# ...

# %%
address = 'Munich, Germany'

geolocator = Nominatim(user_agent="capstoneProject")
location = geolocator.geocode(address, timeout=60, exactly_one=True)
latitude = location.latitude
longitude = location.longitude
print('The decimal coordinates of Munich are {}, {}.'.format(latitude, longitude))
# Out:
# The decimal coordinates of Munich are 48.1371079, 11.5753822.

# %%
# make a copy of the dataframe to get it simply back if needed
df3 = df2.copy()
df3
# Out:
#                                              Location   Latitude  Longitude
# 0                                      Altstadt-Lehel  48.137828  11.574582
# 1                                              Lehel   48.138712  11.588795
# 2                                   Englischer Garten  48.165110  11.606611
# 3                        Ludwigsvorstadt-Isarvorstadt  48.131771  11.555809
# 4                                    Deutsches Museum  48.130039  11.582888
# 5                                         Maxvorstadt  48.146570  11.571445
# 6                                         Königsplatz  48.146316  11.565630
# 7                                      Schwabing-West  48.164417  11.570364
# 8                                       Au-Haidhausen  48.128753  11.590536
# 9                                       Maximilianeum  48.136134  11.595202
# 10                                           Sendling  48.118012  11.539083
# ...

# %% [markdown]
# ### Create map of Munich using latitude and longitude values

# %%
map_munich = folium.Map(location=[latitude, longitude], zoom_start=12)

# add markers to map
for lat, lng, local in zip(df3['Latitude'], df3['Longitude'], df3['Location']):
    label = '{}'.format(local)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_munich)  
map_munich
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# function to repeat the exploring process to all the neighborhoods in Toronto
import urllib
def getNearbyVenues(names, latitudes, longitudes, radius=5000, categoryIds=''):
    try:
        venues_list=[]
        for name, lat, lng in zip(names, latitudes, longitudes):
            #print(name)

            # create the API request URL
            url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, VERSION, lat, lng, radius, LIMIT)

            if (categoryIds != ''):
                url = url + '&categoryId={}'
                url = url.format(categoryIds)

            # make the GET request
            response = requests.get(url).json()
            results = response["response"]['venues']

            # return only relevant information for each nearby venue
            for v in results:
                success = False
                try:
                    category = v['categories'][0]['name']
                    success = True
                except:
                    pass

                if success:
                    venues_list.append([(
                        name, 
                        lat, 
                        lng, 
                        v['name'], 
                        v['location']['lat'], 
                        v['location']['lng'],
                        v['categories'][0]['name']
                    )])

        nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
        nearby_venues.columns = ['Location', 
                  'Location Latitude', 
                  'Location Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    except:
        print(url)
        print(response)
        print(results)
        print(nearby_venues)

    return(nearby_venues)

# %%
import os

base_path = "/home/karlitos/git/Coursera_Capstone/"
filename = "credential.txt"
path_to_file = os.path.join(base_path, filename)
fd = open(path_to_file , 'r')

# %%
fd
# Out:
# <_io.TextIOWrapper name='/home/karlitos/git/Coursera_Capstone/credential.txt' mode='r' encoding='UTF-8'>

# %%
# reading the credential for Foursquare API from an
# external file
LIMIT = fd.readline().strip()
radius = fd.readline().strip()
CLIENT_ID = fd.readline().strip()
CLIENT_SECRET = fd.readline().strip()
VERSION = fd.readline().strip()

# %%
#print(limit)
#print(radius)
#print(CLIENT_ID)
#print(CLIENT_SECRET)
#print(VERSION)

# %% [markdown]
# ### Use category id 4bf58dd8d48988d16c941735 to only get the burger joints

# %%
munich_venues_burger = getNearbyVenues(names=df3['Location'], latitudes=df3['Latitude'], longitudes=df3['Longitude'], radius=1000, categoryIds='4bf58dd8d48988d16c941735')
munich_venues_burger.head()
# Out:
#          Location  Location Latitude  Location Longitude           Venue  \
# 0  Altstadt-Lehel          48.137828           11.574582   Ruff's Burger
# 1  Altstadt-Lehel          48.137828           11.574582   Ruff’s Burger
# 2  Altstadt-Lehel          48.137828           11.574582  Der Kleine Flo
# 3  Altstadt-Lehel          48.137828           11.574582   Ruff’s Burger
# 4  Altstadt-Lehel          48.137828           11.574582     Loco Monaco
#
#    Venue Latitude  Venue Longitude Venue Category
# 0       48.136013        11.574291   Burger Joint
# 1       48.132415        11.567127   Burger Joint
# 2       48.136377        11.568075   Burger Joint
# 3       48.139869        11.562782   Burger Joint
# 4       48.145658        11.570919     Food Truck

# %% [markdown]
# ### How many burger ?

# %%
munich_venues_burger.shape
# Out:
# (129, 7)

# %%
# function to add markers for given venues to map
def addToMap(df, color, existingMap):
    for lat, lng, local, venue, venueCat in zip(df['Venue Latitude'], df['Venue Longitude'], df['Location'], df['Venue'], df['Venue Category']):
        label = '{} ({}) - {}'.format(venue, venueCat, local)
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            popup=label,
            color=color,
            fill=True,
            fill_color=color,
            fill_opacity=0.7).add_to(existingMap)

# %% [markdown]
# ### Map of burger in Munich

# %%
map_munich_burger = folium.Map(location=[latitude, longitude], zoom_start=12)
addToMap(munich_venues_burger, 'red', map_munich_burger)
map_munich_burger
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Highschools

# %%
munich_venues_highschools = getNearbyVenues(names=df3['Location'], latitudes=df3['Latitude'], longitudes=df3['Longitude'], radius=1000, categoryIds='4bf58dd8d48988d13d941735')
munich_venues_highschools.head(n=30)
# Out:
#                         Location  Location Latitude  Location Longitude  \
# 0                 Altstadt-Lehel          48.137828           11.574582
# 1                 Altstadt-Lehel          48.137828           11.574582
# 2                 Altstadt-Lehel          48.137828           11.574582
# 3                 Altstadt-Lehel          48.137828           11.574582
# 4                 Altstadt-Lehel          48.137828           11.574582
# 5                 Altstadt-Lehel          48.137828           11.574582
# 6                         Lehel           48.138712           11.588795
# 7                         Lehel           48.138712           11.588795
# 8                         Lehel           48.138712           11.588795
# 9   Ludwigsvorstadt-Isarvorstadt          48.131771           11.555809
# 10  Ludwigsvorstadt-Isarvorstadt          48.131771           11.555809
# 11  Ludwigsvorstadt-Isarvorstadt          48.131771           11.555809
# ...

# %% [markdown]
# ### Number of highschools

# %%
munich_venues_highschools.shape
# Out:
# (67, 7)

# %% [markdown]
# ### Map of highschools in Munich

# %%
map_munich_highschools = folium.Map(location=[latitude, longitude], zoom_start=12)
addToMap(munich_venues_highschools, 'green', map_munich_highschools)
map_munich_highschools
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Universities

# %%
munich_venues_uni = getNearbyVenues(names=df3['Location'], latitudes=df3['Latitude'], longitudes=df3['Longitude'], radius=1000, categoryIds='4bf58dd8d48988d1ae941735')
munich_venues_uni.head()
# Out:
#          Location  Location Latitude  Location Longitude  \
# 0  Altstadt-Lehel          48.137828           11.574582
# 1  Altstadt-Lehel          48.137828           11.574582
# 2  Altstadt-Lehel          48.137828           11.574582
# 3  Altstadt-Lehel          48.137828           11.574582
# 4  Altstadt-Lehel          48.137828           11.574582
#
#                                 Venue  Venue Latitude  Venue Longitude  \
# 0                    BWS Germanlingua       48.136114        11.569479
# 1                  Universität Bayern       48.135791        11.584822
# 2  International School of Management       48.143411        11.561843
# 3              Hochschule für Politik       48.145613        11.579330
# 4                                 IBZ       48.148479        11.578199
#
#   Venue Category
# 0         School
# 1     University
# 2     University
# 3     University
# 4     University

# %% [markdown]
# ### Number of universities

# %%
munich_venues_uni.shape
# Out:
# (207, 7)

# %%
map_munich_uni = folium.Map(location=[latitude, longitude], zoom_start=12)
addToMap(munich_venues_uni, 'gold', map_munich_uni)
map_munich_uni
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Office

# %%
munich_venues_office = getNearbyVenues(names=df3['Location'], latitudes=df3['Latitude'], longitudes=df3['Longitude'], radius=1000, categoryIds='4d4b7105d754a06375d81259')
munich_venues_office.head()
# Out:
#          Location  Location Latitude  Location Longitude  \
# 0  Altstadt-Lehel          48.137828           11.574582
# 1  Altstadt-Lehel          48.137828           11.574582
# 2  Altstadt-Lehel          48.137828           11.574582
# 3  Altstadt-Lehel          48.137828           11.574582
# 4  Altstadt-Lehel          48.137828           11.574582
#
#                                        Venue  Venue Latitude  Venue Longitude  \
# 0  Dom zu Unserer Lieben Frau (Frauenkirche)       48.138467        11.573273
# 1                                Mariensäule       48.137205        11.575641
# 2                              Neues Rathaus       48.137226        11.575403
# 3                                  St. Peter       48.136530        11.575615
# 4                               Glockenspiel       48.137225        11.575357
#
#         Venue Category
# 0               Church
# 1  Monument / Landmark
# 2            City Hall
# 3               Church
# 4  Monument / Landmark

# %%
munich_venues_office.shape
# Out:
# (1482, 7)

# %%
map_munich_office = folium.Map(location=[latitude, longitude], zoom_start=12)
addToMap(munich_venues_office, 'fuchsia', map_munich_office)
map_munich_office
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def addColumn(startDf, columnTitle, dataDf):
    grouped = dataDf.groupby('Location').count()
    
    for n in startDf['Location']:
        try:
            startDf.loc[startDf['Location'] == n,columnTitle] = grouped.loc[n, 'Venue']
        except:
            startDf.loc[startDf['Location'] == n,columnTitle] = 0

# %%
df_data = df3.copy()
df_data.rename(columns={'Location':'Location'}, inplace=True)
addColumn(df_data, 'Burger', munich_venues_burger)
addColumn(df_data, 'High Schools', munich_venues_highschools)
addColumn(df_data, 'Universities', munich_venues_uni)
addColumn(df_data, 'Offices', munich_venues_office)
df_data
# Out:
#                                              Location   Latitude  Longitude  \
# 0                                      Altstadt-Lehel  48.137828  11.574582
# 1                                              Lehel   48.138712  11.588795
# 2                                   Englischer Garten  48.165110  11.606611
# 3                        Ludwigsvorstadt-Isarvorstadt  48.131771  11.555809
# 4                                    Deutsches Museum  48.130039  11.582888
# 5                                         Maxvorstadt  48.146570  11.571445
# 6                                         Königsplatz  48.146316  11.565630
# 7                                      Schwabing-West  48.164417  11.570364
# 8                                       Au-Haidhausen  48.128753  11.590536
# 9                                       Maximilianeum  48.136134  11.595202
# 10                                           Sendling  48.118012  11.539083
# ...

# %% [markdown]
# ### Here we setted the important and relevance that we want assign to our chosen parameters: burger, schools, universities and offices
# * **burger** = -1
# * **schools** = 1
# * **universities** = 1.5
# * **offices** = 2

# %%
weight_burger = -1
weight_schools = 1
weight_uni = 1.5
weight_offices = 2

# %%
df_weighted = df_data[['Location']].copy()

# %%
df_weighted['Score'] = df_data['Burger'] * weight_burger + df_data['High Schools'] * weight_schools + df_data['Universities'] * weight_uni + df_data['Offices'] * weight_offices
df_weighted = df_weighted.sort_values(by=['Score'], ascending=False)
df_weighted
# Out:
#                                              Location  Score
# 5                                         Maxvorstadt  164.0
# 6                                         Königsplatz  148.5
# 17                                 Schwabing-Freimann  143.5
# 0                                      Altstadt-Lehel  115.0
# 14                                     Oberwiesenfeld  114.0
# 1                                              Lehel   114.0
# 4                                    Deutsches Museum  111.5
# 8                                       Au-Haidhausen  110.5
# 7                                      Schwabing-West  109.0
# 9                                       Maximilianeum  109.0
# 13                              Neuhausen-Nymphenburg  102.0
# 19                                  Münchner Freiheit  100.0
# 3                        Ludwigsvorstadt-Isarvorstadt   99.5
# 12                                   Schwanthalerhöhe   99.5
# ...

# %%
map_munich_result = folium.Map(location=[latitude, longitude], zoom_start=15)

munich_win = df3[df3['Location'] == 'Maxvorstadt']

for lat, lng, local in zip(munich_win['Latitude'], munich_win['Longitude'], munich_win['Location']):
    label = '{}'.format(local)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7).add_to(map_munich_result) 

addToMap(munich_venues_burger[munich_venues_burger['Location'] == 'Maxvorstadt'], 'red', map_munich_result)
addToMap(munich_venues_highschools[munich_venues_highschools['Location'] == 'Maxvorstadt'], 'green', map_munich_result)
addToMap(munich_venues_uni[munich_venues_uni['Location'] == 'Maxvorstadt'], 'gold', map_munich_result)
addToMap(munich_venues_office[munich_venues_office['Location'] == 'Maxvorstadt'], 'fuchsia', map_munich_result)

map_munich_result
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Maxvorstadt is the best site where to start a burger pub according with the weight assigned to the chosen parameters:
# * **burger** = -1
# * **schools** = 1
# * **universities** = 1.5
# * **offices** = 2
